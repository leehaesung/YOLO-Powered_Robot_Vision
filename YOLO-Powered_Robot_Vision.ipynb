# %% [markdown]
# # YOLO-Powered Robot Vision

# %% [markdown]
#     - Update Date: 6th May 2017
#
#     - Edited By LEE, Stephen Haesung

# %% [markdown]
#     - Press "shift" + "Enter" to contnue.

# %% [markdown]
#     - should install both openCV and YOLO.

# %% [markdown]
# ## Using your USB Camera & Latop Camera for image recognition

# %% [markdown]
#     Take a picutre in your robot.

# %%
import os

# %%
# sudo fswebcam -r 1280x720 --no-banner /home/pi/Documents/images/cnn/test_image.png  # Linux & Raspberry Pi
# sudo imagesnap -w 1 /Users/leehaesung/Documents/01_Books/05_Engineering/02_Control_Engineering/06_Machine_Learning/37_TensorFlow/01_DeepLearningZeroToAll_SungKim/test_image.png
os.system('fswebcam -r 1280x720 --no-banner /home/pi/Documents/YOLO-Powered_Robot_Vision/data/test_image.png')
# Out:
# 0

# %% [markdown]
# ##### How to install a webcam:
#     sudo apt-get install fswebcam   (Linux & Raspberry Pi)
#
#     brew install imagesnap   (Mac)

# %% [markdown]
# ## Detecting "test_image.png" taken by the USB Camera

# %%
#  import subprocess
os.system('./darknet detector test cfg/coco.data cfg/yolo.cfg yolo.weights data/test_image.png')
# Out:
# 0

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
test_image = mpimg.imread(os.path.join("predictions.png"))
plt.imshow(test_image)
plt.axis("on")
plt.show()

# %% [markdown]
# ## Using Tiny-YOLO

# %%
os.system('./darknet detector test cfg/voc.data cfg/tiny-yolo-voc.cfg tiny-yolo-voc.weights data/test_image.png -thresh 0.009')
# Out:
# 0

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
test_image = mpimg.imread(os.path.join("predictions.png"))
plt.imshow(test_image)
plt.axis("on")
plt.show()

# %%
# END
